# %% [markdown]
# **SALES PREDICTION USING PYTHON**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/car_purchasing.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.tail()
# Out:
#     customer name                     customer e-mail      country  gender  \
# 495        Walter                 ligula@Cumsociis.ca        Nepal       0
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     Zimbabwe       1
# 497         Pearl       penatibus.et@massanonante.com  Philippines       1
# 498          Nell   Quisque.varius@arcuVivamussit.net     Botswana       1
# 499         Marla           Camaron.marla@hotmail.com       marlal       1
#
#            age  annual Salary  credit card debt    net worth  \
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# 499          45107.22566

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df.isna().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %% [markdown]
# **Drop Irrelevant Columns**

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# **Test Train Split**

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %%
# Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 10)                50
#
#  dense_28 (Dense)            (None, 10)                110
#
#  dense_29 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Model Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 23ms/step - loss: 0.2465 - mean_absolute_error: 0.4754 - val_loss: 0.2392 - val_mean_absolute_error: 0.4657
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1953 - mean_absolute_error: 0.4197 - val_loss: 0.1901 - val_mean_absolute_error: 0.4107
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1499 - mean_absolute_error: 0.3651 - val_loss: 0.1472 - val_mean_absolute_error: 0.3559
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1121 - mean_absolute_error: 0.3105 - val_loss: 0.1078 - val_mean_absolute_error: 0.2976
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0785 - mean_absolute_error: 0.2540 - val_loss: 0.0740 - val_mean_absolute_error: 0.2371
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0506 - mean_absolute_error: 0.1961 - val_loss: 0.0466 - val_mean_absolute_error: 0.1803
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0292 - mean_absolute_error: 0.1443 - val_loss: 0.0277 - val_mean_absolute_error: 0.1334
# Epoch 8/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0165 - mean_absolute_error: 0.1043 - val_loss: 0.0175 - val_mean_absolute_error: 0.1050
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mean_absolute_error: 0.0845 - val_loss: 0.0139 - val_mean_absolute_error: 0.0954
# Epoch 10/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0105 - mean_absolute_error: 0.0796 - val_loss: 0.0130 - val_mean_absolute_error: 0.0917
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0794 - val_loss: 0.0127 - val_mean_absolute_error: 0.0905
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0784 - val_loss: 0.0124 - val_mean_absolute_error: 0.0896
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0773 - val_loss: 0.0123 - val_mean_absolute_error: 0.0892
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0768 - val_loss: 0.0122 - val_mean_absolute_error: 0.0888
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - mean_absolute_error: 0.0761 - val_loss: 0.0119 - val_mean_absolute_error: 0.0878
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0754 - val_loss: 0.0116 - val_mean_absolute_error: 0.0868
# Epoch 17/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0747 - val_loss: 0.0114 - val_mean_absolute_error: 0.0860
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0088 - mean_absolute_error: 0.0741 - val_loss: 0.0111 - val_mean_absolute_error: 0.0850
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0087 - mean_absolute_error: 0.0734 - val_loss: 0.0109 - val_mean_absolute_error: 0.0843
# Epoch 20/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mean_absolute_error: 0.0728 - val_loss: 0.0107 - val_mean_absolute_error: 0.0834
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0722 - val_loss: 0.0106 - val_mean_absolute_error: 0.0828
# Epoch 22/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - mean_absolute_error: 0.0718 - val_loss: 0.0104 - val_mean_absolute_error: 0.0821
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0081 - mean_absolute_error: 0.0712 - val_loss: 0.0103 - val_mean_absolute_error: 0.0814
# Epoch 24/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0706 - val_loss: 0.0101 - val_mean_absolute_error: 0.0806
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0079 - mean_absolute_error: 0.0701 - val_loss: 0.0099 - val_mean_absolute_error: 0.0798
# Epoch 26/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_absolute_error: 0.0696 - val_loss: 0.0097 - val_mean_absolute_error: 0.0791
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0692 - val_loss: 0.0096 - val_mean_absolute_error: 0.0786
# Epoch 28/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0687 - val_loss: 0.0094 - val_mean_absolute_error: 0.0778
# Epoch 29/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_absolute_error: 0.0681 - val_loss: 0.0093 - val_mean_absolute_error: 0.0772
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0073 - mean_absolute_error: 0.0675 - val_loss: 0.0091 - val_mean_absolute_error: 0.0765
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0669 - val_loss: 0.0090 - val_mean_absolute_error: 0.0758
# Epoch 32/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0664 - val_loss: 0.0088 - val_mean_absolute_error: 0.0751
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0659 - val_loss: 0.0086 - val_mean_absolute_error: 0.0745
# Epoch 34/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0068 - mean_absolute_error: 0.0654 - val_loss: 0.0085 - val_mean_absolute_error: 0.0739
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0648 - val_loss: 0.0084 - val_mean_absolute_error: 0.0733
# Epoch 36/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0644 - val_loss: 0.0082 - val_mean_absolute_error: 0.0727
# Epoch 37/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0638 - val_loss: 0.0081 - val_mean_absolute_error: 0.0721
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_absolute_error: 0.0633 - val_loss: 0.0080 - val_mean_absolute_error: 0.0715
# Epoch 39/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0629 - val_loss: 0.0079 - val_mean_absolute_error: 0.0710
# Epoch 40/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0625 - val_loss: 0.0077 - val_mean_absolute_error: 0.0704
# Epoch 41/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0619 - val_loss: 0.0075 - val_mean_absolute_error: 0.0695
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0612 - val_loss: 0.0074 - val_mean_absolute_error: 0.0689
# Epoch 43/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0059 - mean_absolute_error: 0.0607 - val_loss: 0.0074 - val_mean_absolute_error: 0.0686
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_absolute_error: 0.0604 - val_loss: 0.0073 - val_mean_absolute_error: 0.0681
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0598 - val_loss: 0.0070 - val_mean_absolute_error: 0.0670
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0591 - val_loss: 0.0069 - val_mean_absolute_error: 0.0664
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0586 - val_loss: 0.0068 - val_mean_absolute_error: 0.0659
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_absolute_error: 0.0582 - val_loss: 0.0067 - val_mean_absolute_error: 0.0655
# Epoch 49/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - mean_absolute_error: 0.0577 - val_loss: 0.0065 - val_mean_absolute_error: 0.0645
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0052 - mean_absolute_error: 0.0570 - val_loss: 0.0064 - val_mean_absolute_error: 0.0640

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# %%
# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout
plt.show()

# %%
# Evaluate Model

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.7749173584520215
